# %% [markdown]
# 1.1 Create a 1d numpy array called cost price contaning the prices for 3 items.

# %%
import numpy as np
cost= np.array([1500,3000, 5000])
print(cost)
# Out:
# [1500 3000 5000]

# %% [markdown]
# 1.2 Create a 2d numpy array called daily sales representing the number of units sold

# %% [markdown]
# headphones
# smartphones
# speakers

# %%
dailySales = np.array([[10,15,8,12],[5,7,4,6],[2,3,2,4]])
print(dailySales)
# Out:
# [[10 15  8 12]
#  [ 5  7  4  6]
#  [ 2  3  2  4]]

# %% [markdown]
# 1.3 print the shape and dimension of both arrays.

# %%
np.shape(cost)
# Out:
# (3,)

# %%
print(cost.ndim)
# Out:
# 1

# %%
np.shape(dailySales)
# Out:
# (3, 4)

# %%
print(dailySales.ndim)
# Out:
# 2

# %% [markdown]
# 2.1 the manager decides to add 2 bonus units to every product's daily sale. Add 2 to the entire daily sales array.

# %%
print(dailySales + 2)
# Out:
# [[12 17 10 14]
#  [ 7  9  6  8]
#  [ 4  5  4  6]]

# %% [markdown]
# 2.2 calculate total revenue each day

# %%
result= np.dot(cost,dailySales)
print(result)
# Out:
# [40000 58500 34000 56000]

# %% [markdown]
# 2.3 Use np.sqrt() on the sales data to find the square root of all sales values for a statistical curve.

# %%
print(np.sqrt(dailySales))
# Out:
# [[3.16227766 3.87298335 2.82842712 3.46410162]
#  [2.23606798 2.64575131 2.         2.44948974]
#  [1.41421356 1.73205081 1.41421356 2.        ]]

# %% [markdown]
# 3.1 Access the sales for smartwatches(row 1)

# %%
print(dailySales[1])
# Out:
# [5 7 4 6]

# %% [markdown]
# 3.2 Access the sales for all products for the first two days.

# %%
print(dailySales[:,0:2])
# Out:
# [[10 15]
#  [ 5  7]
#  [ 2  3]]

# %% [markdown]
# 3.3 Access the sales of Speakers on Thursday specifically using double indexing.

# %%
print(dailySales[2][3])
# Out:
# 4

# %% [markdown]
# 3.4 Using slicing extract a 2x2 sub array representing sales of headphones and smartwatches for monday and tuesday

# %%
print(dailySales[0:2,1:3])
# Out:
# [[15  8]
#  [ 7  4]]

# %% [markdown]
# 4.1 Flatten the 3x4 daily sales array into a 1d array of 12 elements using .reshape().

# %%
reshaped_sales = dailySales.reshape(1, 12)
print(reshaped_sales)
# Out:
# [[10 15  8 12  5  7  4  6  2  3  2  4]]

# %% [markdown]
# convert the sales data into a 2x6 matrix

# %%
reshaped_sales = dailySales.reshape(2, 6)
print(reshaped_sales)
# Out:
# [[10 15  8 12  5  7]
#  [ 4  6  2  3  2  4]]

# %% [markdown]
# use np.linspace to create an array

# %% [markdown]
# 5.1 use np.random.randit to generate a new 3x4 array of "predicted sales" for the next week with values ranging from 0 to 20.

# %%
predictedSales = np.random.randint(1,21,size=(3,4))
print(predictedSales)
# Out:
# [[18  6  5  1]
#  [20  9  7 10]
#  [18 16  7  8]]

# %% [markdown]
# 5.2 generate a random array of 5 numbers between 0 and 1 using np.random.rand.

# %%
arr = np.random.rand(5)
print(arr)
# Out:
# [0.33587562 0.73760754 0.10090833 0.43155412 0.72673318]

# %% [markdown]
# 5.3 use np.sum to find
# 1. total items sold over all 4 days
# 2. total items sold for each product

# %%
sum = np.sum(dailySales)
print(sum)
# Out:
# 78

# %%
sum = np.sum(dailySales, axis=1)
print(sum)
# Out:
# [45 22 11]

# %%
students = np.array([[78,85,90],[45,60,55],[88,92,95],[30,40,35],[65,70,75]])
print(avg_smarks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 students = np.array([[78,85,90],[45,60,55],[88,92,95],[30,40,35],[65,70,75]])
# ----> 2 print(avg_smarks)
#
# NameError: name 'avg_smarks' is not defined

# %% [markdown]
# A1: Matadata discovery
# determine shape
# find total no
# identify the data type of elements

# %%
np.shape(avg_smarks)
# Out:
# (5,)

# %%
np.size(students)
# Out:
# 15

# %%
np.
# Out:
#   Cell In[116], line 1
#     np.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# A2: Data indexing & slicing
# Extract all marks for the 2nd students
# Extract all marks for the 3rd student across all subjects
# Find the specific mark for student 1 in subject 2

# %%
print(students[1])
# Out:
# [45 60 55]

# %%
print(students[2])
# Out:
# [88 92 95]

# %%
print(students[0][1])
# Out:
# 85

# %% [markdown]
# B1 : Means and averages
# calculate the avg marks for each student
# calculate the avg marks for each subject

# %%
avg_smarks = np.average(students, axis = 1)
print(avg_smarks)
# Out:
# [84.33333333 53.33333333 91.66666667 35.         70.        ]

# %%
avg_marks = np.average(students, axis = 0)
print(avg_marks)
# Out:
# [61.2 69.4 70. ]

# %% [markdown]
# B2: filtering top performers
# Identify and display students whose average marks are >=80

# %%
top = np.where(avg_smarks >=80,avg_smarks,0)
print(top)
# Out:
# [84.33333333  0.         91.66666667  0.          0.        ]

# %% [markdown]
# B3: Gloabal adjustments
# the college decides to add 5 grace marks to every subject for every student.Update the array using broadcasting

# %%
print(students+5)
# Out:
# [[ 83  90  95]
#  [ 50  65  60]
#  [ 93  97 100]
#  [ 35  45  40]
#  [ 70  75  80]]

# %% [markdown]
# C1: Pass/Fail mapping
# create a status matrix
# marks >= 50 - pass
# marks <50 -fail

# %%
marks = np.where(students >= 50,"pass", "fail")
print(marks)
# Out:
# [['pass' 'pass' 'pass']
#  ['fail' 'pass' 'pass']
#  ['pass' 'pass' 'pass']
#  ['fail' 'fail' 'fail']
#  ['pass' 'pass' 'pass']]

# %% [markdown]
# C2: Data cleaning
# to standardize failing grades, replace all marks below 40 will value of 0

# %%
marks = np.where(students < 40,0, students)
print(marks)
# Out:
# [[78 85 90]
#  [45 60 55]
#  [88 92 95]
#  [ 0 40  0]
#  [65 70 75]]

# %% [markdown]
# D1: Grade Allocation apply a grading system baswd on the student Average
# avg>=85 - grade A
# abg>= 70- grade B
# avg>= 50- grade C
# Below 50 - np grade

# %%
grade = np.where(avg_smarks >= 85, "A", np.where(avg_smarks >= 70, "B", np.where(avg_smarks >= 50, "C", "no")))
print(grade)
# Out:
# ['B' 'C' 'A' 'no' 'B']

# %% [markdown]
# E1: the copy vs view challenge
# Create a backup of the marks array
# Modify the original array
# Check if the backup array changed or remained original

# %%
backup = students.copy()
print(backup)
# Out:
# [[78 85 90]
#  [45 60 55]
#  [88 92 95]
#  [30 40 35]
#  [65 70 75]]

# %%
students[2][2]=18
print(students)
# Out:
# [[78 85 90]
#  [45 60 55]
#  [88 92 18]
#  [30 40 35]
#  [65 70 75]]

# %%
print(backup)
# Out:
# [[78 85 90]
#  [45 60 55]
#  [88 92 95]
#  [30 40 35]
#  [65 70 75]]

# %% [markdown]
# Case Study:
# A university moniters electricity usage (in units) of 4 hostels over 7 days
# Array Name = electricity
# Shape = (4,7)
# rows= hostels(h1, h2, h3, h4)
# cols= days(mon-sun)

# %% [markdown]
# A1: Create a numpy array electricuty using np.random.randint:
# values between 120 and 650
# shape(4,7)

# %%
electricity= np.random.randint(120,650,(4,7))
print(electricity)
# Out:
# [[345 168 488 268 392 247 541]
#  [361 466 550 376 585 170 567]
#  [121 128 247 469 163 553 241]
#  [442 473 470 525 222 407 394]]

# %% [markdown]
# A2: print the following attributes of the array:
# Shape, Number of dimensions, total number of elements and data type

# %%
avg_electricity = np.mean(electricity, axis=1)
print(avg_electricity)
# Out:
# [349.85714286 439.28571429 274.57142857 419.        ]

# %%
max_consumption = np.max(electricity,axis=1)
print(max_consumption)
# Out:
# [541 585 553 525]

# %%
max_consumption = np.max(avg_electricity)
print(max_consumption)
# Out:
# 439.2857142857143

# %%
total_consumption = np.sum(electricity,axis=0)
print(total_consumption)
# Out:
# [1269 1235 1755 1638 1362 1377 1743]

# %%
max_cons = np.max(total_consumption)
print(max_cons)
# Out:
# 1755

# %% [markdown]
# If electricity usage on any day is greater than 550 units, a 20% surcharge is applied

# %% [markdown]
# Create a new array penalized_usage such that
# values > 550 = multiplied by 1.20
# all other values remain unchanged

# %%
penalized_usage = np.where(electricity>550,  electricity*1.20 ,electricity)
print(penalized_usage)
# Out:
# [[345.  168.  488.  268.  392.  247.  541. ]
#  [361.  466.  550.  376.  702.  170.  680.4]
#  [121.  128.  247.  469.  163.  663.6 241. ]
#  [442.  473.  470.  525.  222.  407.  394. ]]

# %% [markdown]
# Compare each hostel's daily usage with its own weekly average. Create a boolean matrix where:
# True: Above hostel average
# False: Below or equal to hostel average

# %%
avg_weekly = np.mean(electricity, axis=0)
print(avg_weekly)
# Out:
# [317.25 308.75 438.75 409.5  340.5  344.25 435.75]

# %%
compare = np.where(electricity>avg_weekly, "True", "False")
print(compare)
# Out:
# [['True' 'False' 'True' 'False' 'True' 'False' 'True']
#  ['True' 'True' 'True' 'False' 'True' 'False' 'True']
#  ['False' 'False' 'False' 'True' 'False' 'True' 'False']
#  ['True' 'True' 'True' 'True' 'False' 'True' 'False']]

# %% [markdown]
# Reshape the electricity data into a single row representing weekly usage(shape 1x28)
# reshape the same data into 2 rows and 14 columns.

# %%
reshape = electricity.reshape(1,28)
print(reshape)
# Out:
# [[345 168 488 268 392 247 541 361 466 550 376 585 170 567 121 128 247 469
#   163 553 241 442 473 470 525 222 407 394]]

# %%
reshape = electricity.reshape(2,14)
print(reshape)
# Out:
# [[345 168 488 268 392 247 541 361 466 550 376 585 170 567]
#  [121 128 247 469 163 553 241 442 473 470 525 222 407 394]]

# %% [markdown]
# Copy vs view
# Create ref_backup = electricity
# Create safe_back = electricity.copy()
# Modify one value in the original electricity array
# Observe which backups change.

# %%
ref_backup = electricity
print(ref_backup)
# Out:
# [[345 168 488 268 392 247 541]
#  [361 466 550 376 585 170 567]
#  [121 128 247 469 163 553 241]
#  [442 473 470 525 222 407 394]]

# %%
safe_backup = electricity.copy()
print(safe_backup)
# Out:
# [[345 168 488 268 392 247 541]
#  [361 466 550 376 585 170 567]
#  [121 128 247 469 163 553 241]
#  [442 473 470 525 222 407 394]]

# %%
electricity[3][3]= 450
print(electricity)
# Out:
# [[345 168 488 268 392 247 541]
#  [361 466 550 376 585 170 567]
#  [121 128 247 469 163 553 241]
#  [442 473 470 450 222 407 394]]

# %%
print(ref_backup)
# Out:
# [[345 168 488 268 392 247 541]
#  [361 466 550 376 585 170 567]
#  [121 128 247 469 163 553 241]
#  [442 473 470 450 222 407 394]]

# %%
print(safe_backup)
# Out:
# [[345 168 488 268 392 247 541]
#  [361 466 550 376 585 170 567]
#  [121 128 247 469 163 553 241]
#  [442 473 470 525 222 407 394]]
