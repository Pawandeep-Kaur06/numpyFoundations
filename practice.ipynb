# %%
import numpy as np

# %%
a = np.array([1, 2, 3])

# %%
b = np.array([[1,2,3],
              [4,5,6]])
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
b.shape     # (2,3)
# Out:
# (2, 3)

# %%
b.dtype
# Out:
# dtype('int64')

# %%
np.zeros((2,3))     # all zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3,3))      # all ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye(3)           # identity matrix
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.full((2,2), 7)   # filled with 7
# Out:
# array([[7, 7],
#        [7, 7]])

# %%
np.arange(0,10,2)      # like range()
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0,1,5)     # 5 equally spaced values
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# %%
a + b   # [5 7 9]
# Out:
# array([5, 7, 9])

# %%
a * b   # [4 10 18]
# Out:
# array([ 4, 10, 18])

# %%
a ** 2  # [1 4 9]
# Out:
# array([1, 4, 9])

# %%
np.sum(a)
# Out:
# np.int64(6)

# %%
np.mean(a)
# Out:
# np.float64(2.0)

# %%
np.min(a)
# Out:
# np.int64(1)

# %%
np.max(a)
# Out:
# np.int64(3)

# %%
np.std(a)
# Out:
# np.float64(0.816496580927726)

# %%
b = np.array([[1,2,3],
              [4,5,6]])
np.sum(b, axis=1)   # row-wise
# Out:
# array([ 6, 15])

# %%
np.sum(b, axis=0)   # column-wise
# Out:
# array([5, 7, 9])

# %%
np.max(b)
# Out:
# np.int64(6)

# %% [markdown]
# Two dimensions are compatible if:
#
# They are equal
# OR
#
# One of them is 1

# %%
a = np.array([[1,2,3],
              [4,5,6]])   # shape (2,3)

b = np.array([10,20,30])  # shape (3,)
a+b
# Out:
# array([[11, 22, 33],
#        [14, 25, 36]])

# %%
a = np.array([[1],[2],[3]])   # (3,1)
b = np.array([10,20,30])      # (3,)

# %%
A = np.array([[1,2],
              [3,4]])

B = np.array([[5,6],
              [7,8]])

A @ B
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.dot(A, B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
np.linalg.det(A)
# Out:
# np.float64(-2.0000000000000004)

# %%
np.random.randint(5)
# Out:
# 3

# %%
np.random.rand(5)        # uniform [0,1)
# Out:
# array([0.05044627, 0.23447739, 0.794219  , 0.94136878, 0.50044185])

# %%
np.random.randn(3)       # normal distribution
# Out:
# array([ 0.63553807,  0.98571757, -1.04178947])

# %%
np.random.rand(2,3)
# Out:
# array([[0.56337412, 0.16703415, 0.80737057],
#        [0.21777493, 0.75969371, 0.94758883]])

# %%
np.random.randint(0,10,5)
# Out:
# array([2, 1, 9, 9, 3], dtype=int32)

# %%
np.random.seed(42)
